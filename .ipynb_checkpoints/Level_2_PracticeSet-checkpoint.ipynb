# %%
a=10
b=20

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a>b)
print(a<b)
print(a!=b)
print(a==b)
print(a>=b)
print(a<=b)
print(a is b)
print(a is not b)
# Out:
# 30
# -10
# 200
# 0.5
# False
# True
# True
# False
# False
# True
# False
# True

# %%
num=int(input("Enter Number to Check Even or Odd : "))
if num % 2 == 0:
    print("Number is Even")
else:
    print("Number is Odd")
# Out:
# Enter Number to Check Even or Odd :  10
# Number is Even

# %%
a=int(input("Enter first Number :"))
b=int(input("Enter second Number :"))

if a>b:
    print("First Number is larger")
else:
    print("Second Number is Larger")
# Out:
# Enter first Number : 30
# Enter second Number : 10
# First Number is larger

# %%
age=int(input("Enter your age : "))

if age>18:
    print("Your Eligible to Vote")
elif age==18:
    print("Welcome Young boy ur now eligible to vote")
else : 
    print("palu tagi bajjo ra bacchaa")
# Out:
# Enter your age :  12
# palu tagi bajjo ra bacchaa

# %%
name=input("Enter Name : ")
age=int(input("Enter Age  :"))
print(f"{name:>10},{age:>10}")
print(f"{name:<10}, {age:>10}")
print(f"{name:^10}, {age:^10}")
# Out:
# Enter Name :  Nagesh
# Enter Age  : 23
#     Nagesh,        23
# Nagesh    ,         23
#   Nagesh  ,     23

# %%
a=40
b=30
b+=a
print(b)
b-=a
print(b)
b*=a
print(b)
b/=a
print(b)
# Out:
# 70
# 30
# 1200
# 30.0

# %%
print("Hello friends\nmy name is Nagesh \nwe are here to learn python for data science")
# Out:
# Hello friends
# my name is Nagesh
# we are here to learn python for data science

# %%
num=int(input("Enter Number :"))
if num>0:
    print("Positive")
elif num<0:
    print("Negetive")
else : 
    print("Zero")
# Out:
# Enter Number : -1
# Negetive

# %%
a=90
b=80
c=50

if a>b and a>c:
    print("A is largest")
elif b>a and b>c:
    print("B is largest")
else:
    print("C is Largest")
# Out:
# A is largest
