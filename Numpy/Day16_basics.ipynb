# %% [markdown]
# #Numpy

# %%
import numpy as np

# %%
a=np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
b=np.zeros(5)
print(b)
# Out:
# [0. 0. 0. 0. 0.]

# %%
c=np.ones(5)
print(c)
# Out:
# [1. 1. 1. 1. 1.]

# %%
d=np.arange(1,10)
print(d)
# Out:
# [1 2 3 4 5 6 7 8 9]

# %% [markdown]
# #Operations

# %%
a+5
# Out:
# array([6, 7, 8, 9])

# %%
a-2
# Out:
# array([-1,  0,  1,  2])

# %%
a*2
# Out:
# array([2, 4, 6, 8])

# %%
a**2
# Out:
# array([ 1,  4,  9, 16])

# %% [markdown]
# #Functions

# %%
np.sum(a)
# Out:
# np.int64(10)

# %%
np.mean(a)
# Out:
# np.float64(2.5)

# %%
np.max(a)
# Out:
# np.int64(4)
