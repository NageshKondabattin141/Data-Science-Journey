# %% [markdown]
# #Data types in numpy
# in numpy the default values of int is int64 and for float its float64
# we can use int32 and float32 instead for less memory and fast performance

# %%
import numpy as np

# %%
arr=np.array([21,23,1,25,34])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.astype("float64")
# Out:
# array([21., 23.,  1., 25., 34.])

# %%
arr.astype("int32")
# Out:
# array([21, 23,  1, 25, 34], dtype=int32)

# %%
arr.astype("float32")
# Out:
# array([21., 23.,  1., 25., 34.], dtype=float32)

# %%
arr2=np.array([23,96,8,9,6],dtype="int32")

# %%
arr2.dtype
# Out:
# dtype('int32')

# %%
arr.nbytes
# Out:
# 40

# %%
arr2.nbytes
# Out:
# 20

# %%
arr3=np.array([1+2j,2+3j,4+6j],dtype="complex128")
print(arr3)
# Out:
# [1.+2.j 2.+3.j 4.+6.j]

# %% [markdown]
# #Always choose right datatype is very important for optimizing the memory usage.
#
# using smallest datatype which fit the data actually improves the performance.
#
# smaller datatypes actually performs the fast operations so its ensures precision.

# %% [markdown]
# #Broadcasting

# %%
#Normalization

arr=np.array([12,32,21],
            [30,10,20],
            [9,23,12],
            [54,23,54])

mean=arr.mean(axis=0)
std=data.std(axis=0)
normalized_data= (data - mean )/ std
print(normalized_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 #Normalization
# ----> 3 arr=np.array([12,32,21],
#       4             [30,10,20],
#       5             [9,23,12],
#       6             [54,23,54])
#       8 mean=arr.mean(axis=0)
#       9 std=data.std(axis=0)
#
# TypeError: array() takes from 1 to 2 positional arguments but 4 were given
