# %%
a=5 
b=9

a = a+b
b = a-b
a = a-b

print("After Swaping : ",a,b)
# Out:
# After Swaping :  9 5

# %%
name="Nagesh"
age=23

print(name,age+5)
# Out:
# Nagesh 28

# %%
sub1,sub2,sub3,sub4,sub5=60,30,77,97,50
avg=(sub1+sub2+sub3+sub4+sub5)/5

percentage=((sub1+sub2+sub3+sub4+sub5)/500)*100


print("Average of all marks : ",avg)
print("Percentage : ",percentage)
# Out:
# Average of all marks :  62.8
# Percentage :  62.8

# %%
strnum="120"
intnum=int(strnum)
floatnum=float(strnum)

print(strnum,intnum,floatnum)
print(type(strnum))
print(type(intnum))
print(type(floatnum))
# Out:
# 120 120 120.0
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
celcius=int(input("Enter Temperature in Celcius : "))
fehrenhite=(celcius*1.8)+32

print("Temperature in Fehrenhite : ",fehrenhite)
# Out:
# Enter Temperature in Celcius :  40
# Temperature in Fehrenhite :  104.0

# %%
m_sal=int(input("Enter Monthly Salary : "))
y_sal=m_sal*12

print("This is your Yeary Package : ",float(y_sal))
# Out:
# Enter Monthly Salary :  3
# This is your Yeary Package :  36.0

# %%
strname=input("Enter a String : ")
print(len(strname),type(strname))
# Out:
# Enter a String :  Nagesh
# 6 <class 'str'>
